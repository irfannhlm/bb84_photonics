# %%
# %pip install json
# %pip install struct
# %pip install numpy
# %pip install matplotlib
# %pip install photonforge
# %pip install siepic-forge
# %pip install tidy3d
# Out:
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# ERROR: Could not find a version that satisfies the requirement struct (from versions: none)
# ERROR: No matching distribution found for struct
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting photonforge
#   Downloading photonforge-1.2.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting tidy3d==2.9.*,>=2.9.1 (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading tidy3d-2.9.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from photonforge) (2.0.2)
# Requirement already satisfied: scipy>=1.15 in /usr/local/lib/python3.12/dist-packages (from photonforge) (1.16.3)
# Requirement already satisfied: uvicorn>=0.34 in /usr/local/lib/python3.12/dist-packages (from photonforge) (0.38.0)
# Requirement already satisfied: fastapi>=0.115 in /usr/local/lib/python3.12/dist-packages (from photonforge) (0.123.10)
# Requirement already satisfied: jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from photonforge) (3.1.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (6.0.3)
# Requirement already satisfied: autograd>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.8.0)
# Collecting boto3<2.0.0,>=1.28.0 (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading boto3-1.42.17-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: click<9.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (8.3.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.12.0)
# Collecting h5netcdf==1.0.2 (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading h5netcdf-1.0.2-py2.py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: h5py<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.15.1)
# Requirement already satisfied: importlib-metadata>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (8.7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.2.2)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.12.3)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.10.1)
# Collecting pyroots>=0.5.0 (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading pyroots-0.5.0-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.32.4)
# Collecting responses (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading responses-0.25.8-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: rich<14.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (13.9.4)
# Requirement already satisfied: shapely<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.1.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.10.2)
# Requirement already satisfied: xarray>=2023.08 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.12.0)
# Collecting networkx<3.0.0,>=2.6.3 (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Collecting rtree==1.2.0 (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading Rtree-1.2.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.1 kB)
# Collecting trimesh<5,>=4 (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading trimesh-4.10.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from h5netcdf==1.0.2->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (25.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1->photonforge) (3.0.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.34->photonforge) (0.16.0)
# Collecting botocore<1.43.0,>=1.42.17 (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading botocore-1.42.17-py3-none-any.whl.metadata (5.9 kB)
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading jmespath-1.0.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting s3transfer<0.17.0,>=0.16.0 (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge)
#   Downloading s3transfer-0.16.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.0.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.19.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi>=0.115->photonforge) (4.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.3)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (3.2.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (0.1.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge) (1.17.0)
# Downloading photonforge-1.2.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 21.4 MB/s eta 0:00:00
# Downloading tidy3d-2.9.3-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.9 MB/s eta 0:00:00
# Downloading h5netcdf-1.0.2-py2.py3-none-any.whl (24 kB)
# Downloading Rtree-1.2.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (535 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 535.2/535.2 kB 32.6 MB/s eta 0:00:00
# Downloading boto3-1.42.17-py3-none-any.whl (140 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 10.5 MB/s eta 0:00:00
# Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 58.6 MB/s eta 0:00:00
# Downloading pyroots-0.5.0-py2.py3-none-any.whl (17 kB)
# Downloading trimesh-4.10.1-py3-none-any.whl (737 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.0/737.0 kB 38.5 MB/s eta 0:00:00
# Downloading responses-0.25.8-py3-none-any.whl (34 kB)
# Downloading botocore-1.42.17-py3-none-any.whl (14.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 89.8 MB/s eta 0:00:00
# Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.1 MB/s eta 0:00:00
# Installing collected packages: trimesh, rtree, pyroots, networkx, jmespath, responses, h5netcdf, botocore, s3transfer, boto3, tidy3d, photonforge
#   Attempting uninstall: rtree
#     Found existing installation: rtree 1.4.1
#     Uninstalling rtree-1.4.1:
#       Successfully uninstalled rtree-1.4.1
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.6.1
#     Uninstalling networkx-3.6.1:
#       Successfully uninstalled networkx-3.6.1
#   Attempting uninstall: h5netcdf
#     Found existing installation: h5netcdf 1.7.3
#     Uninstalling h5netcdf-1.7.3:
#       Successfully uninstalled h5netcdf-1.7.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spopt 0.7.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# scikit-image 0.25.2 requires networkx>=3.0, but you have networkx 2.8.8 which is incompatible.
# mapclassify 2.10.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# momepy 0.10.0 requires networkx>=3.2, but you have networkx 2.8.8 which is incompatible.
# Successfully installed boto3-1.42.17 botocore-1.42.17 h5netcdf-1.0.2 jmespath-1.0.1 networkx-2.8.8 photonforge-1.2.3 pyroots-0.5.0 responses-0.25.8 rtree-1.2.0 s3transfer-0.16.0 tidy3d-2.9.3 trimesh-4.10.1
# Collecting siepic-forge
#   Downloading siepic_forge-1.1.2-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: photonforge>=1.2.1 in /usr/local/lib/python3.12/dist-packages (from siepic-forge) (1.2.3)
# Requirement already satisfied: tidy3d==2.9.*,>=2.9.1 in /usr/local/lib/python3.12/dist-packages (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.9.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from photonforge>=1.2.1->siepic-forge) (2.0.2)
# Requirement already satisfied: scipy>=1.15 in /usr/local/lib/python3.12/dist-packages (from photonforge>=1.2.1->siepic-forge) (1.16.3)
# Requirement already satisfied: uvicorn>=0.34 in /usr/local/lib/python3.12/dist-packages (from photonforge>=1.2.1->siepic-forge) (0.38.0)
# Requirement already satisfied: fastapi>=0.115 in /usr/local/lib/python3.12/dist-packages (from photonforge>=1.2.1->siepic-forge) (0.123.10)
# Requirement already satisfied: jinja2>=3.1 in /usr/local/lib/python3.12/dist-packages (from photonforge>=1.2.1->siepic-forge) (3.1.6)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (6.0.3)
# Requirement already satisfied: autograd>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.8.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.42.17)
# Requirement already satisfied: click<9.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (8.3.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.12.0)
# Requirement already satisfied: h5netcdf==1.0.2 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.0.2)
# Requirement already satisfied: h5py<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.15.1)
# Requirement already satisfied: importlib-metadata>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (8.7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.10.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.2.2)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.12.3)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.10.1)
# Requirement already satisfied: pyroots>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.32.4)
# Requirement already satisfied: responses in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.25.8)
# Requirement already satisfied: rich<14.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (13.9.4)
# Requirement already satisfied: shapely<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.1.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.10.2)
# Requirement already satisfied: xarray>=2023.08 in /usr/local/lib/python3.12/dist-packages (from tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.12.0)
# Requirement already satisfied: networkx<3.0.0,>=2.6.3 in /usr/local/lib/python3.12/dist-packages (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.8.8)
# Requirement already satisfied: rtree==1.2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.2.0)
# Requirement already satisfied: trimesh<5,>=4 in /usr/local/lib/python3.12/dist-packages (from tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (4.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from h5netcdf==1.0.2->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (25.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge>=1.2.1->siepic-forge) (0.50.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge>=1.2.1->siepic-forge) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi>=0.115->photonforge>=1.2.1->siepic-forge) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.1->photonforge>=1.2.1->siepic-forge) (3.0.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn>=0.34->photonforge>=1.2.1->siepic-forge) (0.16.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.17 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.42.17)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.0.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.19.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi>=0.115->photonforge>=1.2.1->siepic-forge) (4.12.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.3)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (3.2.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (0.1.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->tidy3d==2.9.*,>=2.9.1->tidy3d[trimesh]==2.9.*,>=2.9.1->photonforge>=1.2.1->siepic-forge) (1.17.0)
# Downloading siepic_forge-1.1.2-py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: siepic-forge
# Successfully installed siepic-forge-1.1.2
# Requirement already satisfied: tidy3d in /usr/local/lib/python3.12/dist-packages (2.9.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from tidy3d) (6.0.3)
# Requirement already satisfied: autograd>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (1.8.0)
# Requirement already satisfied: boto3<2.0.0,>=1.28.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (1.42.17)
# Requirement already satisfied: click<9.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (8.3.1)
# Requirement already satisfied: dask in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2025.12.0)
# Requirement already satisfied: h5netcdf==1.0.2 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (1.0.2)
# Requirement already satisfied: h5py<4.0.0,>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (3.15.1)
# Requirement already satisfied: importlib-metadata>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (8.7.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from tidy3d) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from tidy3d) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.2.2)
# Requirement already satisfied: pydantic<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.12.3)
# Requirement already satisfied: pyjwt in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.10.1)
# Requirement already satisfied: pyroots>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (0.5.0)
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.32.4)
# Requirement already satisfied: responses in /usr/local/lib/python3.12/dist-packages (from tidy3d) (0.25.8)
# Requirement already satisfied: rich<14.0,>=13.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (13.9.4)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from tidy3d) (1.16.3)
# Requirement already satisfied: shapely<3.0,>=2.0 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2.1.2)
# Requirement already satisfied: toml in /usr/local/lib/python3.12/dist-packages (from tidy3d) (0.10.2)
# Requirement already satisfied: xarray>=2023.08 in /usr/local/lib/python3.12/dist-packages (from tidy3d) (2025.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from h5netcdf==1.0.2->tidy3d) (25.0)
# Requirement already satisfied: botocore<1.43.0,>=1.42.17 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d) (1.42.17)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d) (1.0.1)
# Requirement already satisfied: s3transfer<0.17.0,>=0.16.0 in /usr/local/lib/python3.12/dist-packages (from boto3<2.0.0,>=1.28.0->tidy3d) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata>=6.0.0->tidy3d) (3.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d) (2.41.4)
# Requirement already satisfied: typing-extensions>=4.14.1 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0,>=2.0->tidy3d) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.31.0->tidy3d) (2025.11.12)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich<14.0,>=13.0->tidy3d) (2.19.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->tidy3d) (2025.3)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d) (3.1.2)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d) (2025.3.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d) (1.4.2)
# Requirement already satisfied: toolz>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from dask->tidy3d) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->tidy3d) (3.2.5)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich<14.0,>=13.0->tidy3d) (0.1.2)
# Requirement already satisfied: locket in /usr/local/lib/python3.12/dist-packages (from partd>=1.4.0->dask->tidy3d) (1.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->tidy3d) (1.17.0)

# %%
import tidy3d.web as web
web.configure("Ibql1MdAL8o9sCstHbnB8tw3vXpdZpWviz6FlQ826ojd5pUy")
# Out:
# API key configured successfully.

# %%
import numpy as np
import matplotlib.pyplot as plt
import photonforge as pf
import siepic_forge as siepic
import tidy3d as td

tech = siepic.ebeam()
pf.config.default_technology = tech

# Initialize live viewer for real-time visualization
from photonforge.live_viewer import LiveViewer
viewer = LiveViewer(5005)

wavelengths = np.linspace(1.53, 1.57, 101)
freqs = pf.C_0 / wavelengths
print(f'Wavelength range: {wavelengths[0]:.3f} - {wavelengths[-1]:.3f} µm')
print(f'Center wavelength: {wavelengths[len(wavelengths)//2]:.3f} µm')
# Out:
# LiveViewer started at http://localhost:5005
# Wavelength range: 1.530 - 1.570 µm
# Center wavelength: 1.550 µm

# %% [markdown]
# ## Thermal Phase Shifter Model
# Custom model for thermally-tunable phase shifters.

# %%
plasmonic_gold_layer = pf.LayerSpec(layer=(15, 0), description="Metal", color="F5BC00", pattern="xx")

tech.add_layer("Plasmonic Gold", plasmonic_gold_layer)
# Out:
# Name: SiEPIC EBeam
# Version: 0.4.32
#
# Layers:
#         Name          Layer    Description    Color    Pattern
# --------------------------------------------------------------
# Si                    (1, 0)   Waveguides   #ff80a818     \\
# PinRec               (1, 10)   SiEPIC       #00408018     /
# PinRecM              (1, 11)   SiEPIC       #00408018     /
# Si_Litho193nm        (1, 69)   Waveguides   #cc80a818     \
# Waveguide            (1, 99)   Waveguides   #ff80a818     \
# Si slab               (2, 0)   Waveguides   #80a8ff18     /
# SiN                   (4, 0)   Waveguides   #a6cee318     \\
# Oxide open (to BOX)   (6, 0)   Waveguides   #ffae0018     \
# Text                 (10, 0)                #0000ff18     \
# M1_heater            (11, 0)   Metal        #ebc63418     xx
# M2_router            (12, 0)   Metal        #90857018     xx
# M_Open               (13, 0)   Metal        #3471eb18     xx
# Plasmonic Gold       (15, 0)   Metal        #f5bc00ff     xx
# Si N                 (20, 0)   Doping       #7000ff18     \\
# Si N++               (24, 0)   Doping       #0000ff18     :
# VC                   (40, 0)   Metal        #3a027f18     xx
# DevRec               (68, 0)   SiEPIC       #00408018   hollow
# FbrTgt               (81, 0)   SiEPIC       #00408018     /
# FloorPlan            (99, 0)   Misc         #8000ff18   hollow
# SEM                  (200, 0)  Misc         #ff00ff18     \
# Deep Trench          (201, 0)  Misc         #c0c0c018   solid
# Keep out             (202, 0)  Misc         #a0a0c018     //
# Isolation Trench     (203, 0)  Misc         #c0c0c018   solid
# Dicing               (210, 0)  Misc         #a0a0c018   solid
# Chip design area     (290, 0)  Misc         #80005718   hollow
# FDTD                 (733, 0)  SiEPIC       #80005718   hollow
# BlackBox             (998, 0)  SiEPIC       #00408018   solid
# Errors               (999, 0)  SiEPIC       #00008018     /
#
# Extrusion Specs:
# #                Mask                Limits (μm)  Sidewal (°)        Opt. Medium                   Elec. Medium
# -------------------------------------------------------------------------------------------------------------------------
# 0  'Oxide open (to BOX)'                0, inf         0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
# 1  'Si'                                0, 0.22         0       cSi_Li1993_293K           Si
# 2  'Si slab'                           0, 0.09         0       cSi_Li1993_293K           Si
# 3  'SiN'                                0, 0.4         0       Si3N4_Luke2015_PMLStable  Si3N4
# 4  'M2_router' + 'M1_heater'          2.42, 2.62       0       W_Werner2009              LossyMetalMedium(conductivity=1…
# 5  'M2_router'                        2.62, 3.02       0       Au_Olmon2012evaporated    LossyMetalMedium(conductivity=1…
# 6  'M_Open'                           3.02, inf        0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
# 7  'Deep Trench' + 'Isolation Tren…   -inf, inf        0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
#
# Ports:
#         Name         Classification            Description             Width (μm)  Limits (μm)  Radius (μm)    Modes     Target n_eff         Path profiles (μm)         Voltage path  Current path
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# MM_SiN_TE_1550_3000     optical      Multimode SiN Strip TE 1550 nm,…      8        -2.5, 2.9        0           7           2.1       'SiN': 3
# MM_TE_1550_2000         optical      Multimode Strip TE 1550 nm, w=2…      6         -2, 2.22        0           12          3.5       'Si': 2
# MM_TE_1550_3000         optical      Multimode Strip TE 1550 nm, w=3…      6         -2, 2.22        0           17          3.5       'Si': 3
# Rib_TE_1310_350         optical      Rib (90 nm slab) TE 1310 nm, w=…     2.35       -1, 1.22        0           1           3.5       'Si': 0.35, 'Si slab': 3
# Rib_TE_1550_500         optical      Rib (90 nm slab) TE 1550 nm, w=…     2.5        -1, 1.22        0           1           3.5       'Si': 0.5, 'Si slab': 3
# SiN_TE-TM_1550_1000     optical      SiN Strip TM 1550 nm, w=1000 nm       3        -1.5, 1.9        0           2           2.1       'SiN': 1
# SiN_TE_1310_750         optical      SiN Strip TE 1310 nm, w=750 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.75
# SiN_TE_1310_800         optical      SiN Strip TE 1310 nm, w=800 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.8
# SiN_TE_1550_1000        optical      SiN Strip TE 1550 nm, w=1000 nm       3         -1, 1.4         0           1           2.1       'SiN': 1
# SiN_TE_1550_750         optical      SiN Strip TE 1550 nm, w=750 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.75
# SiN_TE_1550_800         optical      SiN Strip TE 1550 nm, w=800 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.8
# SiN_TE_895_450          optical      SiN Strip TE 895 nm, w=450 nm         2         -1, 1.4         0           1           2.1       'SiN': 0.45
# SiN_TM_1310_750         optical      SiN Strip TM 1310 nm, w=750 nm        3        -1.5, 1.9        0       1 + 1 (TM)      2.1       'SiN': 0.75
# SiN_TM_1550_1000        optical      SiN Strip TM 1550 nm, w=1000 nm       3        -1.5, 1.9        0       1 + 1 (TM)      2.1       'SiN': 1
# Slot_TE_1550_500        optical      Slot TE 1550 nm, w=500 nm, gap=…      2         -1, 1.22        0           1           3.5       'Si': 0.2 (-0.15), 'Si': 0.2 (+…
# TE-TM_1550_450          optical      Strip TE-TM 1550, w=450 nm            2         -1, 1.22        0           2           3.5       'Si': 0.45
# TE_1310_350             optical      Strip TE 1310 nm, w=350 nm            2         -1, 1.22        0           1           3.5       'Si': 0.35
# TE_1310_410             optical      Strip TE 1310 nm, w=410 nm            2         -1, 1.22        0           1           3.5       'Si': 0.41
# TE_1550_500             optical      Strip TE 1550 nm, w=500 nm            2         -1, 1.22        0           1           3.5       'Si': 0.5
# TM_1310_350             optical      Strip TM 1310 nm, w=350 nm            2         -1, 1.22        0       1 + 1 (TM)      3.5       'Si': 0.35
# TM_1550_500             optical      Strip TM 1550 nm, w=500 nm           2.5        -1, 1.22        0       1 + 1 (TM)      3.5       'Si': 0.5
# eskid_TE_1550           optical      eskid TE 1550                        3.31       -1, 1.22        0           1           3.5       'Si': 0.35, 'Si': 0.06 (+0.265)…
#
# Background medium:
# - Optical: SiO2_Palik_Lossless
# - Electrical: SiO2
#
# Connections: []

# %%
plasmonic_gold_gap = 0.03  # Gap between waveguide and gold
plasmonic_gold_thickness = 0.14  # Thickness of the gold layer
wg_height = 0.22

plasmonic_gold_extrusion = pf.ExtrusionSpec(mask_spec=pf.MaskSpec((15, 0)),
                                            medium={"optical": td.material_library['Au']['JohnsonChristy1972'],
                                                    "electrical": td.LossyMetalMedium(conductivity=17.0, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms': 0.001, 'frequency_sampling_points': 20, 'log_sampling': True, 'type': 'SurfaceImpedanceFitterParam'}, frequency_range=(100000000.0, 200000000000.0))},
                                                    limits=(wg_height+plasmonic_gold_gap, wg_height+plasmonic_gold_gap+plasmonic_gold_thickness), sidewall_angle=0, reference="top")
tech.insert_extrusion_spec(4, plasmonic_gold_extrusion)
# Out:
# Name: SiEPIC EBeam
# Version: 0.4.32
#
# Layers:
#         Name          Layer    Description    Color    Pattern
# --------------------------------------------------------------
# Si                    (1, 0)   Waveguides   #ff80a818     \\
# PinRec               (1, 10)   SiEPIC       #00408018     /
# PinRecM              (1, 11)   SiEPIC       #00408018     /
# Si_Litho193nm        (1, 69)   Waveguides   #cc80a818     \
# Waveguide            (1, 99)   Waveguides   #ff80a818     \
# Si slab               (2, 0)   Waveguides   #80a8ff18     /
# SiN                   (4, 0)   Waveguides   #a6cee318     \\
# Oxide open (to BOX)   (6, 0)   Waveguides   #ffae0018     \
# Text                 (10, 0)                #0000ff18     \
# M1_heater            (11, 0)   Metal        #ebc63418     xx
# M2_router            (12, 0)   Metal        #90857018     xx
# M_Open               (13, 0)   Metal        #3471eb18     xx
# Plasmonic Gold       (15, 0)   Metal        #f5bc00ff     xx
# Si N                 (20, 0)   Doping       #7000ff18     \\
# Si N++               (24, 0)   Doping       #0000ff18     :
# VC                   (40, 0)   Metal        #3a027f18     xx
# DevRec               (68, 0)   SiEPIC       #00408018   hollow
# FbrTgt               (81, 0)   SiEPIC       #00408018     /
# FloorPlan            (99, 0)   Misc         #8000ff18   hollow
# SEM                  (200, 0)  Misc         #ff00ff18     \
# Deep Trench          (201, 0)  Misc         #c0c0c018   solid
# Keep out             (202, 0)  Misc         #a0a0c018     //
# Isolation Trench     (203, 0)  Misc         #c0c0c018   solid
# Dicing               (210, 0)  Misc         #a0a0c018   solid
# Chip design area     (290, 0)  Misc         #80005718   hollow
# FDTD                 (733, 0)  SiEPIC       #80005718   hollow
# BlackBox             (998, 0)  SiEPIC       #00408018   solid
# Errors               (999, 0)  SiEPIC       #00008018     /
#
# Extrusion Specs:
# #                Mask                Limits (μm)  Sidewal (°)        Opt. Medium                   Elec. Medium
# -------------------------------------------------------------------------------------------------------------------------
# 0  'Oxide open (to BOX)'                0, inf         0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
# 1  'Si'                                0, 0.22         0       cSi_Li1993_293K           Si
# 2  'Si slab'                           0, 0.09         0       cSi_Li1993_293K           Si
# 3  'SiN'                                0, 0.4         0       Si3N4_Luke2015_PMLStable  Si3N4
# 4  'Plasmonic Gold'                   0.25, 0.39       0       Au_JohnsonChristy1972     LossyMetalMedium(conductivity=1…
# 5  'M2_router' + 'M1_heater'          2.42, 2.62       0       W_Werner2009              LossyMetalMedium(conductivity=1…
# 6  'M2_router'                        2.62, 3.02       0       Au_Olmon2012evaporated    LossyMetalMedium(conductivity=1…
# 7  'M_Open'                           3.02, inf        0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
# 8  'Deep Trench' + 'Isolation Tren…   -inf, inf        0       Medium(permittivity=1.0)  Medium(permittivity=1.0)
#
# Ports:
#         Name         Classification            Description             Width (μm)  Limits (μm)  Radius (μm)    Modes     Target n_eff         Path profiles (μm)         Voltage path  Current path
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# MM_SiN_TE_1550_3000     optical      Multimode SiN Strip TE 1550 nm,…      8        -2.5, 2.9        0           7           2.1       'SiN': 3
# MM_TE_1550_2000         optical      Multimode Strip TE 1550 nm, w=2…      6         -2, 2.22        0           12          3.5       'Si': 2
# MM_TE_1550_3000         optical      Multimode Strip TE 1550 nm, w=3…      6         -2, 2.22        0           17          3.5       'Si': 3
# Rib_TE_1310_350         optical      Rib (90 nm slab) TE 1310 nm, w=…     2.35       -1, 1.22        0           1           3.5       'Si': 0.35, 'Si slab': 3
# Rib_TE_1550_500         optical      Rib (90 nm slab) TE 1550 nm, w=…     2.5        -1, 1.22        0           1           3.5       'Si': 0.5, 'Si slab': 3
# SiN_TE-TM_1550_1000     optical      SiN Strip TM 1550 nm, w=1000 nm       3        -1.5, 1.9        0           2           2.1       'SiN': 1
# SiN_TE_1310_750         optical      SiN Strip TE 1310 nm, w=750 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.75
# SiN_TE_1310_800         optical      SiN Strip TE 1310 nm, w=800 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.8
# SiN_TE_1550_1000        optical      SiN Strip TE 1550 nm, w=1000 nm       3         -1, 1.4         0           1           2.1       'SiN': 1
# SiN_TE_1550_750         optical      SiN Strip TE 1550 nm, w=750 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.75
# SiN_TE_1550_800         optical      SiN Strip TE 1550 nm, w=800 nm        3         -1, 1.4         0           1           2.1       'SiN': 0.8
# SiN_TE_895_450          optical      SiN Strip TE 895 nm, w=450 nm         2         -1, 1.4         0           1           2.1       'SiN': 0.45
# SiN_TM_1310_750         optical      SiN Strip TM 1310 nm, w=750 nm        3        -1.5, 1.9        0       1 + 1 (TM)      2.1       'SiN': 0.75
# SiN_TM_1550_1000        optical      SiN Strip TM 1550 nm, w=1000 nm       3        -1.5, 1.9        0       1 + 1 (TM)      2.1       'SiN': 1
# Slot_TE_1550_500        optical      Slot TE 1550 nm, w=500 nm, gap=…      2         -1, 1.22        0           1           3.5       'Si': 0.2 (-0.15), 'Si': 0.2 (+…
# TE-TM_1550_450          optical      Strip TE-TM 1550, w=450 nm            2         -1, 1.22        0           2           3.5       'Si': 0.45
# TE_1310_350             optical      Strip TE 1310 nm, w=350 nm            2         -1, 1.22        0           1           3.5       'Si': 0.35
# TE_1310_410             optical      Strip TE 1310 nm, w=410 nm            2         -1, 1.22        0           1           3.5       'Si': 0.41
# TE_1550_500             optical      Strip TE 1550 nm, w=500 nm            2         -1, 1.22        0           1           3.5       'Si': 0.5
# TM_1310_350             optical      Strip TM 1310 nm, w=350 nm            2         -1, 1.22        0       1 + 1 (TM)      3.5       'Si': 0.35
# TM_1550_500             optical      Strip TM 1550 nm, w=500 nm           2.5        -1, 1.22        0       1 + 1 (TM)      3.5       'Si': 0.5
# eskid_TE_1550           optical      eskid TE 1550                        3.31       -1, 1.22        0           1           3.5       'Si': 0.35, 'Si': 0.06 (+0.265)…
#
# Background medium:
# - Optical: SiO2_Palik_Lossless
# - Electrical: SiO2
#
# Connections: []

# %%
class ThermalModel(pf.Model):
    def __init__(self, n_complex, voltage=0, coefficient=3e-4):
        super().__init__(
            n_complex=n_complex,
            voltage=voltage,
            coefficient=coefficient,
        )
        self.n_complex = np.array(n_complex, ndmin=2)
        self.voltage = voltage
        self.coefficient = coefficient

    def __copy__(self):
        return ThermalModel(self.n_complex, self.voltage, self.coefficient)

    def __deepcopy__(self, memo=None):
        # n_complex is an array, so we want to make sure to create a deep copy of it.
        # Other values (voltage and coefficient) are immutable (floats), so we can use them directly.
        return ThermalModel(self.n_complex.copy(), self.voltage, self.coefficient)

    def __repr__(self):
        return f"ThermalModel({self.n_complex!r}, {self.voltage!r}, {self.coefficient!r})"

    def __str__(self):
        return f"ThermalModel at {self.voltage} V"

    @property
    def as_bytes(self):
        coeffs = struct.pack("<2d", self.voltage, self.coefficient)
        shape = struct.pack("<2l", *self.n_complex.shape)
        n_data = self.n_complex.astype(complex).tobytes()
        # Add version 0 as first byte
        return b"\x00" + coeffs + shape + n_data

    @classmethod
    def from_bytes(cls, byte_repr):
        version = byte_repr[0]
        if version != 0:
            raise RuntimeError(f"Incompatible version for ThermalModel: {version}")

        byte_repr = byte_repr[1:]
        fmt = "<2d2l"
        head_len = struct.calcsize(fmt)
        voltage, coefficient, rows, cols = struct.unpack(fmt, byte_repr[:head_len])

        byte_repr = byte_repr[head_len:]
        n_complex = np.frombuffer(byte_repr, dtype=complex).reshape((rows, cols))

        return cls(n_complex, voltage, coefficient)

    @pf.cache_s_matrix
    def start(self, component, frequencies, voltage=None, **kwargs):
        # Allow overriding voltage as an `s_matrix` kwarg too
        if voltage is None:
            voltage = self.voltage
        n_complex = self.n_complex + self.coefficient * voltage**2
        wg_model = pf.WaveguideModel(n_complex)
        return wg_model.start(component, frequencies, **kwargs)


pf.register_model_class(ThermalModel)

# %% [markdown]
# ## PSR + MMI Architecture
# This section implements the PSR and 2x2 MMI, then assembles the full Bob V2 circuit.

# %%
tech.ports["TM_1550_500"]
# Out:
# PortSpec(description="Strip TM 1550 nm, w=500 nm", width=2.5, limits=(-1, 1.22), num_modes=1, added_solver_modes=1, polarization="TM", target_neff=3.5, default_radius=0, path_profiles=[(0.5, 0, (1, 0))])

# %%
tech.ports["TE_1550_500"]
# Out:
# PortSpec(description="Strip TE 1550 nm, w=500 nm", width=2, limits=(-1, 1.22), num_modes=1, added_solver_modes=0, polarization="", target_neff=3.5, default_radius=0, path_profiles=[(0.5, 0, (1, 0))])

# %%
core_width = 0.5  # input/output port core width
output_separation = 1.5  # separation between TE ports at the split output

# %%
dual_mode_spec = tech.ports["TE_1550_500"].copy()
dual_mode_spec.num_modes = 2  # Use both modes

tech.add_port("TE-TM_1550_500", dual_mode_spec)
tech.ports["TE-TM_1550_500"]
# Out:
# PortSpec(description="Strip TE 1550 nm, w=500 nm", width=2, limits=(-1, 1.22), num_modes=2, added_solver_modes=0, polarization="", target_neff=3.5, default_radius=0, path_profiles=[(0.5, 0, (1, 0))])

# %%
@pf.parametric_component
def create_psr(
    *,
    rotator_length=70,
    mid_taper_length=5,
    splitter_length=100,
    taper_length=10,
    rotator_width=1.1,
    taper_width=0.1,
    coupler_width1=0.95,
    coupler_width2=0.65,
    splitter_width1=0.2,
    gap=0.15,
    s_factor=6,
    model_kwargs={},
):
    component = pf.Component()

    s_bend_length = s_factor * output_separation
    splitter_width2 = coupler_width1 + splitter_width1 - coupler_width2
    if splitter_width2 <= 0:
        raise ValueError("Invalid input")

    p0 = (0, 0)
    p1 = (
        rotator_length
        + mid_taper_length
        + splitter_length
        + s_bend_length
        + taper_length,
        -output_separation,
    )
    p2 = (
        rotator_length
        + mid_taper_length
        + splitter_length
        + s_bend_length
        + taper_length,
        gap + 0.5 * (coupler_width2 + splitter_width2),
    )
    tapers = [
        pf.Path(p0, core_width).segment((rotator_length, 0), taper_width),
        pf.Path(p1, core_width).segment((-taper_length, 0), taper_width, relative=True),
        pf.Path(p2, core_width).segment((-taper_length, 0), taper_width, relative=True),
    ]

    main_path = (
        pf.Path((0, 0), core_width)
        .segment((rotator_length, 0), rotator_width)
        .segment((mid_taper_length, 0), coupler_width1, relative=True)
        .segment((splitter_length, 0), coupler_width2, relative=True)
        .s_bend((s_bend_length, -output_separation), euler_fraction=0.5, relative=True)
        .segment((taper_length, 0), core_width, relative=True)
    )

    coupled_path = (
        pf.Path(p2, core_width)
        .segment((-taper_length, 0), splitter_width2, relative=True)
        .segment((-s_bend_length, 0), relative=True)
        .segment((-splitter_length, 0), splitter_width1, relative=True)
    )
    component.add("Si", *tapers, "Si slab", main_path, coupled_path)

    component.add_port(
        [
            pf.Port(p0, 0, "TE-TM_1550_500"),
            pf.Port(p1, 180, "TE_1550_500"),
            pf.Port(p2, 180, "TE_1550_500"),
        ]
    )

    component.add_model(pf.Tidy3DModel(**model_kwargs), "Tidy3D")
    return component


psr = create_psr()
viewer(psr)
# TM -> TE P2 AS V> then connect to phase shifter
# TE -> TE P1 AS H>
# Out:
# Component(name="create_psr_EUNWBUI37VWE7TX5GAABMW7JDEZUD32BUIT3IY44GGD6IPI4I3LA", technology=Technology(name="SiEPIC EBeam", version="0.4.32", layers={"BlackBox": LayerSpec(layer=(998, 0), description="SiEPIC", color="#00408018", pattern="solid"), "Chip design area": LayerSpec(layer=(290, 0), description="Misc", color="#80005718", pattern="hollow"), "Deep Trench": LayerSpec(layer=(201, 0), description="Misc", color="#c0c0c018", pattern="solid"), "DevRec": LayerSpec(layer=(68, 0), description="SiEPIC", color="#00408018", pattern="hollow"), "Dicing": LayerSpec(layer=(210, 0), description="Misc", color="#a0a0c018", pattern="solid"), "Errors": LayerSpec(layer=(999, 0), description="SiEPIC", color="#00008018", pattern="/"), "FDTD": LayerSpec(layer=(733, 0), description="SiEPIC", color="#80005718", pattern="hollow"), "FbrTgt": LayerSpec(layer=(81, 0), description="SiEPIC", color="#00408018", pattern="/"), "FloorPlan": LayerSpec(layer=(99, 0), description="Misc", color="#8000ff18", pattern="hollow"), "Isolation Trench": LayerSpec(layer=(203, 0), description="Misc", color="#c0c0c018", pattern="solid"), "Keep out": LayerSpec(layer=(202, 0), description="Misc", color="#a0a0c018", pattern="//"), "M1_heater": LayerSpec(layer=(11, 0), description="Metal", color="#ebc63418", pattern="xx"), "M2_router": LayerSpec(layer=(12, 0), description="Metal", color="#90857018", pattern="xx"), "M_Open": LayerSpec(layer=(13, 0), description="Metal", color="#3471eb18", pattern="xx"), "Oxide open (to BOX)": LayerSpec(layer=(6, 0), description="Waveguides", color="#ffae0018", pattern="\"), "PinRec": LayerSpec(layer=(1, 10), description="SiEPIC", color="#00408018", pattern="/"), "PinRecM": LayerSpec(layer=(1, 11), description="SiEPIC", color="#00408018", pattern="/"), "Plasmonic Gold": LayerSpec(layer=(15, 0), description="Metal", color="#f5bc00ff", pattern="xx"), "SEM": LayerSpec(layer=(200, 0), description="Misc", color="#ff00ff18", pattern="\"), "Si": LayerSpec(layer=(1, 0), description="Waveguides", color="#ff80a818", pattern="\\"), "Si N": LayerSpec(layer=(20, 0), description="Doping", color="#7000ff18", pattern="\\"), "Si N++": LayerSpec(layer=(24, 0), description="Doping", color="#0000ff18", pattern=":"), "Si slab": LayerSpec(layer=(2, 0), description="Waveguides", color="#80a8ff18", pattern="/"), "SiN": LayerSpec(layer=(4, 0), description="Waveguides", color="#a6cee318", pattern="\\"), "Si_Litho193nm": LayerSpec(layer=(1, 69), description="Waveguides", color="#cc80a818", pattern="\"), "Text": LayerSpec(layer=(10, 0), description="", color="#0000ff18", pattern="\"), "VC": LayerSpec(layer=(40, 0), description="Metal", color="#3a027f18", pattern="xx"), "Waveguide": LayerSpec(layer=(1, 99), description="Waveguides", color="#ff80a818", pattern="\")}, extrusion_specs=[ExtrusionSpec(mask_spec=MaskSpec((6, 0)), medium=Medium(permittivity=1.0), limits=(0, 2e+07), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((1, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.22), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((2, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.09), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((4, 0)), medium={"optical": Si3N4_Luke2015_PMLStable, "electrical": Si3N4}, limits=(0, 0.4), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((15, 0)), medium={"optical": Au_JohnsonChristy1972, "electrical": LossyMetalMedium(conductivity=17.0, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms': 0.001, 'frequency_sampling_points': 20, 'log_sampling': True, 'type': 'SurfaceImpedanceFitterParam'}, frequency_range=(100000000.0, 200000000000.0))}, limits=(0.25, 0.39), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec(operand0=[MaskSpec((12, 0)), MaskSpec((11, 0))], operand1=[], operation='+'), medium={"optical": W_Werner2009, "electrical": LossyMetalMedium(conductivity=1.6, fit_param={'attrs': ...

# %%
@pf.parametric_component
def create_2x2_mmi_heated_input(*, port_spec='TE_1550_500', mmi_width=6.0, mmi_length=30, taper_width=2.0, taper_length=10, input_wg_length=50):
    c = pf.Component('MMI_2x2_Heated_Input')

    # --- 1. OPTICAL GEOMETRY ---

    # A. The MMI Body (Center)
    mmi_body = pf.Rectangle(center=(mmi_length/2, 0), size=(mmi_length, mmi_width))
    input_offset = mmi_width / 4

    # B. The Tapers
    # Input Tapers (Left side)
    taper_in_bot = pf.Path(origin=(-taper_length, -input_offset), width=0.5).segment(endpoint=(0, -input_offset), width=taper_width)
    taper_in_top = pf.Path(origin=(-taper_length, input_offset), width=0.5).segment(endpoint=(0, input_offset), width=taper_width)

    # Output Tapers (Right side)
    taper_out_bot = pf.Path(origin=(mmi_length, -input_offset), width=taper_width).segment(endpoint=(mmi_length + taper_length, -input_offset), width=0.5)
    taper_out_top = pf.Path(origin=(mmi_length, input_offset), width=taper_width).segment(endpoint=(mmi_length + taper_length, input_offset), width=0.5)

    # C. The Input Waveguides (The new part)
    # Bottom Input Waveguide (P0) - No Heater
    wg_in_bot = pf.Path(
        origin=(-taper_length - input_wg_length, -input_offset),
        width=0.5
    ).segment(
        endpoint=(-taper_length, -input_offset),
        width=0.5
    )

    # Top Input Waveguide (P1) - HEATED
    wg_in_top = pf.Path(
        origin=(-taper_length - input_wg_length, input_offset),
        width=0.5
    ).segment(
        endpoint=(-taper_length, input_offset),
        width=0.5
    )

    # Add all optical structures
    c.add((1, 0), mmi_body)
    c.add((1, 0), taper_in_bot, taper_in_top, taper_out_bot, taper_out_top)
    c.add((1, 0), wg_in_bot, wg_in_top)

    # Detect ports automatically (should pick up the ends of the new input waveguides)
    c.add_port(c.detect_ports([port_spec]))

    # Placing heater ONLY on the Top Input Waveguide (P1)
    heater_width = 2.0 # Standard waveguide heater width
    heater_length = input_wg_length - 10 # Leave some gap for bends/connectors
    heater_x_center = -taper_length - (input_wg_length / 2)
    heater_y_center = input_offset # On the top arm

    # Heater Metal (Layer 11)
    heater = pf.Rectangle(
        center=(heater_x_center, heater_y_center),
        size=(heater_length, heater_width)
    )
    c.add((11, 0), heater)

    # --- TERMINALS & ROUTING ---
    terminal_width = 10
    pad_offset = 30 # Distance above the arm

    # Route UP from the heater to the pads
    # Start: Left end of heater
    route_vp = pf.Path(
        origin=(heater_x_center - heater_length/2 + 2, heater_y_center + heater_width/2),
        width=terminal_width
    ).segment(
        endpoint=(heater_x_center - heater_length/2 + 2, heater_y_center + pad_offset),
        width=terminal_width
    )

    # Start: Right end of heater
    route_vn = pf.Path(
        origin=(heater_x_center + heater_length/2 - 2, heater_y_center + heater_width/2),
        width=terminal_width
    ).segment(
        endpoint=(heater_x_center + heater_length/2 - 2, heater_y_center + pad_offset),
        width=terminal_width
    )

    c.add((12, 0), route_vp, route_vn)

    # --- MODELS ---
    c.add_model(pf.CircuitModel(), 'CircuitModel')

    return c

# Verify
mmi_heated_input = create_2x2_mmi_heated_input()
print(f'MMI with Heated Input created. Terminals: {list(mmi_heated_input.terminals.keys())}')
viewer(mmi_heated_input)
# Out:
# MMI with Heated Input created. Terminals: []
# Component(name="MMI_2x2_Heated_Input", technology=Technology(name="SiEPIC EBeam", version="0.4.32", layers={"BlackBox": LayerSpec(layer=(998, 0), description="SiEPIC", color="#00408018", pattern="solid"), "Chip design area": LayerSpec(layer=(290, 0), description="Misc", color="#80005718", pattern="hollow"), "Deep Trench": LayerSpec(layer=(201, 0), description="Misc", color="#c0c0c018", pattern="solid"), "DevRec": LayerSpec(layer=(68, 0), description="SiEPIC", color="#00408018", pattern="hollow"), "Dicing": LayerSpec(layer=(210, 0), description="Misc", color="#a0a0c018", pattern="solid"), "Errors": LayerSpec(layer=(999, 0), description="SiEPIC", color="#00008018", pattern="/"), "FDTD": LayerSpec(layer=(733, 0), description="SiEPIC", color="#80005718", pattern="hollow"), "FbrTgt": LayerSpec(layer=(81, 0), description="SiEPIC", color="#00408018", pattern="/"), "FloorPlan": LayerSpec(layer=(99, 0), description="Misc", color="#8000ff18", pattern="hollow"), "Isolation Trench": LayerSpec(layer=(203, 0), description="Misc", color="#c0c0c018", pattern="solid"), "Keep out": LayerSpec(layer=(202, 0), description="Misc", color="#a0a0c018", pattern="//"), "M1_heater": LayerSpec(layer=(11, 0), description="Metal", color="#ebc63418", pattern="xx"), "M2_router": LayerSpec(layer=(12, 0), description="Metal", color="#90857018", pattern="xx"), "M_Open": LayerSpec(layer=(13, 0), description="Metal", color="#3471eb18", pattern="xx"), "Oxide open (to BOX)": LayerSpec(layer=(6, 0), description="Waveguides", color="#ffae0018", pattern="\"), "PinRec": LayerSpec(layer=(1, 10), description="SiEPIC", color="#00408018", pattern="/"), "PinRecM": LayerSpec(layer=(1, 11), description="SiEPIC", color="#00408018", pattern="/"), "Plasmonic Gold": LayerSpec(layer=(15, 0), description="Metal", color="#f5bc00ff", pattern="xx"), "SEM": LayerSpec(layer=(200, 0), description="Misc", color="#ff00ff18", pattern="\"), "Si": LayerSpec(layer=(1, 0), description="Waveguides", color="#ff80a818", pattern="\\"), "Si N": LayerSpec(layer=(20, 0), description="Doping", color="#7000ff18", pattern="\\"), "Si N++": LayerSpec(layer=(24, 0), description="Doping", color="#0000ff18", pattern=":"), "Si slab": LayerSpec(layer=(2, 0), description="Waveguides", color="#80a8ff18", pattern="/"), "SiN": LayerSpec(layer=(4, 0), description="Waveguides", color="#a6cee318", pattern="\\"), "Si_Litho193nm": LayerSpec(layer=(1, 69), description="Waveguides", color="#cc80a818", pattern="\"), "Text": LayerSpec(layer=(10, 0), description="", color="#0000ff18", pattern="\"), "VC": LayerSpec(layer=(40, 0), description="Metal", color="#3a027f18", pattern="xx"), "Waveguide": LayerSpec(layer=(1, 99), description="Waveguides", color="#ff80a818", pattern="\")}, extrusion_specs=[ExtrusionSpec(mask_spec=MaskSpec((6, 0)), medium=Medium(permittivity=1.0), limits=(0, 2e+07), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((1, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.22), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((2, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.09), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((4, 0)), medium={"optical": Si3N4_Luke2015_PMLStable, "electrical": Si3N4}, limits=(0, 0.4), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((15, 0)), medium={"optical": Au_JohnsonChristy1972, "electrical": LossyMetalMedium(conductivity=17.0, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms': 0.001, 'frequency_sampling_points': 20, 'log_sampling': True, 'type': 'SurfaceImpedanceFitterParam'}, frequency_range=(100000000.0, 200000000000.0))}, limits=(0.25, 0.39), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec(operand0=[MaskSpec((12, 0)), MaskSpec((11, 0))], operand1=[], operation='+'), medium={"optical": W_Werner2009, "electrical": LossyMetalMedium(conductivity=1.6, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms':  ...

# %%
# Assemble Bob V2 circuit
bob_v2 = pf.Component('BOB_Receiver_v2_PSR_MMI')

# --- DEFINITIONS ---
# 1. Standardize Ports: Use Strip for everything to avoid mismatches
port_spec_std = 'TE_1550_500'

straight_v2 = pf.parametric.straight(port_spec=port_spec_std, length=20)
gc_v2 = siepic.component('ebeam_gc_te1550') # Standard Strip GC

# We don't need the transition if everything is Strip.
# If you strictly need a Rib phase shifter, you need TWO transitions (Strip->Rib, then Rib->Strip).
# For now, let's use a Strip Phase Shifter for stability:
phase_shifter_v2 = pf.parametric.straight(name='ps_v2', port_spec=port_spec_std, length=50)

# Thermal Model (Updated for Strip)
alpha = 10
kappa = (alpha * wavelengths * 1e-4 * np.log(10)) / (40 * np.pi)
mode_solver_v2 = pf.port_modes(port=phase_shifter_v2.ports['P0'], frequencies=freqs)
n_complex_v2 = mode_solver_v2.data.n_complex.values.T + 1j * kappa
thermal_model_v2 = ThermalModel(n_complex=n_complex_v2, coefficient=3e-4)
phase_shifter_v2.add_model(thermal_model_v2, 'Thermal')

psr_v2 = create_psr() # Assuming this defaults to Strip
mmi_v2 = create_2x2_mmi_heated_input()    # Assuming this defaults to Strip
# ... (Previous definitions remain the same) ...

# --- ASSEMBLY ---

# 1. Place References
psr_ref = bob_v2.add_reference(psr_v2)
mmi_ref = bob_v2.add_reference(mmi_v2)

# --- FLIP THE PSR VERTICALLY ---
# Mirrors across the line y=0 (the x-axis)
psr_ref.mirror((0, 0),(1, 0))

# 2. Connect Components

# B. MOVE THE MMI TO THE RIGHT (Crucial Step)
# Instead of snapping it to the PSR, we place it 30 microns away.
# This creates the necessary "runway" for the S-bends to work without looping.
mmi_ref.x_min = psr_ref.x_max + 10 # panjangin mmi biar ga loop
mmi_ref.y_mid = psr_ref.y_mid + 13.8 # Roughly align vertically

# C. Route Top Arm (PSR Top -> MMI Top)
# Even though this is "straight", using route() ensures it bridges the 30um gap perfectly.
route_top = pf.parametric.route(
    port1=psr_ref['P1'],  # Check if P1 is Top on your PSR
    port2=mmi_ref['P1'],  # Top Input (Heated)
    radius=10.0
)
bob_v2.add_reference(route_top)

# D. Route Bottom Arm (PSR Bottom -> MMI Bottom)
route_bot = pf.parametric.route(
    port1=psr_ref['P2'], # Check if P2 is Bottom on your PSR
    port2=mmi_ref['P0'], # Bottom Input
    radius=10.0          # REQUIRED: Prevents the 'float' error
)
bob_v2.add_reference(route_bot)

# --- 1. FIX THE PORTS (The Dictionary Method) ---
bob_v2.add_port(bob_v2.detect_ports(["TE_1550_500"], on_boundary="x"))

print('Bob V2 assembled with correct spacing.')
bob_v2.add_model(pf.Tidy3DModel(), "Tidy3D")
viewer(bob_v2)
# Out:
# Progress: 100%
# Bob V2 assembled with correct spacing.
# Component(name="BOB_Receiver_v2_PSR_MMI", technology=Technology(name="SiEPIC EBeam", version="0.4.32", layers={"BlackBox": LayerSpec(layer=(998, 0), description="SiEPIC", color="#00408018", pattern="solid"), "Chip design area": LayerSpec(layer=(290, 0), description="Misc", color="#80005718", pattern="hollow"), "Deep Trench": LayerSpec(layer=(201, 0), description="Misc", color="#c0c0c018", pattern="solid"), "DevRec": LayerSpec(layer=(68, 0), description="SiEPIC", color="#00408018", pattern="hollow"), "Dicing": LayerSpec(layer=(210, 0), description="Misc", color="#a0a0c018", pattern="solid"), "Errors": LayerSpec(layer=(999, 0), description="SiEPIC", color="#00008018", pattern="/"), "FDTD": LayerSpec(layer=(733, 0), description="SiEPIC", color="#80005718", pattern="hollow"), "FbrTgt": LayerSpec(layer=(81, 0), description="SiEPIC", color="#00408018", pattern="/"), "FloorPlan": LayerSpec(layer=(99, 0), description="Misc", color="#8000ff18", pattern="hollow"), "Isolation Trench": LayerSpec(layer=(203, 0), description="Misc", color="#c0c0c018", pattern="solid"), "Keep out": LayerSpec(layer=(202, 0), description="Misc", color="#a0a0c018", pattern="//"), "M1_heater": LayerSpec(layer=(11, 0), description="Metal", color="#ebc63418", pattern="xx"), "M2_router": LayerSpec(layer=(12, 0), description="Metal", color="#90857018", pattern="xx"), "M_Open": LayerSpec(layer=(13, 0), description="Metal", color="#3471eb18", pattern="xx"), "Oxide open (to BOX)": LayerSpec(layer=(6, 0), description="Waveguides", color="#ffae0018", pattern="\"), "PinRec": LayerSpec(layer=(1, 10), description="SiEPIC", color="#00408018", pattern="/"), "PinRecM": LayerSpec(layer=(1, 11), description="SiEPIC", color="#00408018", pattern="/"), "Plasmonic Gold": LayerSpec(layer=(15, 0), description="Metal", color="#f5bc00ff", pattern="xx"), "SEM": LayerSpec(layer=(200, 0), description="Misc", color="#ff00ff18", pattern="\"), "Si": LayerSpec(layer=(1, 0), description="Waveguides", color="#ff80a818", pattern="\\"), "Si N": LayerSpec(layer=(20, 0), description="Doping", color="#7000ff18", pattern="\\"), "Si N++": LayerSpec(layer=(24, 0), description="Doping", color="#0000ff18", pattern=":"), "Si slab": LayerSpec(layer=(2, 0), description="Waveguides", color="#80a8ff18", pattern="/"), "SiN": LayerSpec(layer=(4, 0), description="Waveguides", color="#a6cee318", pattern="\\"), "Si_Litho193nm": LayerSpec(layer=(1, 69), description="Waveguides", color="#cc80a818", pattern="\"), "Text": LayerSpec(layer=(10, 0), description="", color="#0000ff18", pattern="\"), "VC": LayerSpec(layer=(40, 0), description="Metal", color="#3a027f18", pattern="xx"), "Waveguide": LayerSpec(layer=(1, 99), description="Waveguides", color="#ff80a818", pattern="\")}, extrusion_specs=[ExtrusionSpec(mask_spec=MaskSpec((6, 0)), medium=Medium(permittivity=1.0), limits=(0, 2e+07), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((1, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.22), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((2, 0)), medium={"optical": cSi_Li1993_293K, "electrical": Si}, limits=(0, 0.09), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((4, 0)), medium={"optical": Si3N4_Luke2015_PMLStable, "electrical": Si3N4}, limits=(0, 0.4), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec((15, 0)), medium={"optical": Au_JohnsonChristy1972, "electrical": LossyMetalMedium(conductivity=17.0, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms': 0.001, 'frequency_sampling_points': 20, 'log_sampling': True, 'type': 'SurfaceImpedanceFitterParam'}, frequency_range=(100000000.0, 200000000000.0))}, limits=(0.25, 0.39), sidewall_angle=0, reference="top"), ExtrusionSpec(mask_spec=MaskSpec(operand0=[MaskSpec((12, 0)), MaskSpec((11, 0))], operand1=[], operation='+'), medium={"optical": W_Werner2009, "electrical": LossyMetalMedium(conductivity=1.6, fit_param={'attrs': {}, 'max_num_poles': 16, 'tolerance_rms ...

# %% [markdown]
# ## Simulation and Verification
# The following cells run the S-matrix simulations and plot the results for each stage.

# %%
# %pip install sax
# Out:
# Requirement already satisfied: sax in /usr/local/lib/python3.12/dist-packages (0.15.18)
# Requirement already satisfied: flax>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from sax) (0.10.7)
# Requirement already satisfied: jax>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from sax) (0.7.2)
# Requirement already satisfied: jaxtyping>=0.2.38 in /usr/local/lib/python3.12/dist-packages (from sax) (0.3.4)
# Requirement already satisfied: klujax>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from sax) (0.4.3)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from sax) (1.3.1)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from sax) (3.10.0)
# Requirement already satisfied: natsort>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from sax) (8.4.0)
# Requirement already satisfied: networkx>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from sax) (3.6.1)
# Requirement already satisfied: numpy>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from sax) (2.4.0)
# Requirement already satisfied: orjson>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from sax) (3.11.5)
# Requirement already satisfied: pydantic>=2.10.0 in /usr/local/lib/python3.12/dist-packages (from sax) (2.12.3)
# Requirement already satisfied: pyyaml>=6.0.0 in /usr/local/lib/python3.12/dist-packages (from sax) (6.0.3)
# Requirement already satisfied: scikit-rf>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from sax) (1.9.0)
# Requirement already satisfied: sympy>=1.14.0 in /usr/local/lib/python3.12/dist-packages (from sax) (1.14.0)
# Requirement already satisfied: typing-extensions>=4.13.2 in /usr/local/lib/python3.12/dist-packages (from sax) (4.15.0)
# Requirement already satisfied: xarray>=2025.1.2 in /usr/local/lib/python3.12/dist-packages (from sax) (2025.12.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (1.1.2)
# Requirement already satisfied: optax in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (0.2.6)
# Requirement already satisfied: orbax-checkpoint in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (0.11.31)
# Requirement already satisfied: tensorstore in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (0.1.80)
# Requirement already satisfied: rich>=11.1 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (13.9.4)
# Requirement already satisfied: treescope>=0.1.7 in /usr/local/lib/python3.12/dist-packages (from flax>=0.10.0->sax) (0.1.10)
# Requirement already satisfied: jaxlib<=0.7.2,>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.0->sax) (0.7.2)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.0->sax) (0.5.4)
# Requirement already satisfied: opt_einsum in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.0->sax) (3.4.0)
# Requirement already satisfied: scipy>=1.13 in /usr/local/lib/python3.12/dist-packages (from jax>=0.6.0->sax) (1.16.3)
# Requirement already satisfied: wadler-lindig>=0.1.3 in /usr/local/lib/python3.12/dist-packages (from jaxtyping>=0.2.38->sax) (0.1.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.0.0->sax) (2.9.0.post0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.0->sax) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.0->sax) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.10.0->sax) (0.4.2)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.12/dist-packages (from scikit-rf>=1.8.0->sax) (2.2.2)
# Requirement already satisfied: pre-commit>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from scikit-rf>=1.8.0->sax) (4.5.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.14.0->sax) (1.3.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1->scikit-rf>=1.8.0->sax) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.1->scikit-rf>=1.8.0->sax) (2025.3)
# Requirement already satisfied: cfgv>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (3.5.0)
# Requirement already satisfied: identify>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (2.6.15)
# Requirement already satisfied: nodeenv>=0.11.1 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (1.10.0)
# Requirement already satisfied: virtualenv>=20.10.0 in /usr/local/lib/python3.12/dist-packages (from pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (20.35.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->sax) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.10.0->sax) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=11.1->flax>=0.10.0->sax) (2.19.2)
# Requirement already satisfied: absl-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from optax->flax>=0.10.0->sax) (1.4.0)
# Requirement already satisfied: chex>=0.1.87 in /usr/local/lib/python3.12/dist-packages (from optax->flax>=0.10.0->sax) (0.1.90)
# Requirement already satisfied: etils[epath,epy] in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (1.13.0)
# Requirement already satisfied: nest_asyncio in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (1.6.0)
# Requirement already satisfied: aiofiles in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (24.1.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (5.29.5)
# Requirement already satisfied: humanize in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (4.14.0)
# Requirement already satisfied: simplejson>=3.16.0 in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (3.20.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from orbax-checkpoint->flax>=0.10.0->sax) (5.9.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax>=0.10.0->sax) (75.2.0)
# Requirement already satisfied: toolz>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from chex>=0.1.87->optax->flax>=0.10.0->sax) (0.12.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1->flax>=0.10.0->sax) (0.1.2)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (0.4.0)
# Requirement already satisfied: filelock<4,>=3.12.2 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (3.20.0)
# Requirement already satisfied: platformdirs<5,>=3.9.1 in /usr/local/lib/python3.12/dist-packages (from virtualenv>=20.10.0->pre-commit>=3.5.0->scikit-rf>=1.8.0->sax) (4.5.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.0->sax) (2025.3.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.0->sax) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.12/dist-packages (from etils[epath,epy]->orbax-checkpoint->flax>=0.10.0->sax) (3.23.0)

# %%
import jax.numpy as jnp
import sax
import matplotlib.pyplot as plt

# --- 1. DEFINE COMPONENT MODELS (The Physics Math) ---

def psr_model():
    """
    Polarization Splitter Rotator S-Matrix.
    Maps Input(TE) -> Top Arm (P1).
    Maps Input(TM) -> Bottom Arm (P2).
    """
    # Standard single-mode S-matrix usually doesn't handle polarization modes directly
    # unless we define ports like "in@te" and "in@tm".
    # For simplicity, we assume:
    # Port 'in_te' connects to Top Arm.
    # Port 'in_tm' connects to Bottom Arm.
    return sax.reciprocal({
        ("in_te", "out_top"): 1.0,
        ("in_tm", "out_bot"): 1.0,
    })

def heater_model(voltage=0.0):
    """
    Active Waveguide S-Matrix.
    Applies phase shift based on voltage: phi = - pi/2 * (V / V_pi)^2
    """
    V_pi = 2.0 # Assume 2 Volts is required for Pi shift
    # We want -90 deg (-pi/2) shift.
    # Phase equation: exp(j * phi)
    phi = - (jnp.pi) * (voltage / V_pi)**2
    transmission = jnp.exp(1j * phi)

    return sax.reciprocal({
        ("P0", "P1"): transmission
    })

def mmi2x2_model():
    """
    Standard 2x2 MMI (90-degree Hybrid).
    """
    S = (1.0/jnp.sqrt(2)) * jnp.array([
        [1, 1j],
        [1j, 1]
    ])
    return sax.reciprocal({
        ("in1", "out1"): S[0,0], ("in1", "out2"): S[0,1],
        ("in2", "out1"): S[1,0], ("in2", "out2"): S[1,1],
    })

# --- 2. BUILD THE CIRCUIT NETLIST ---
# This connects the models exactly like your layout.

bob_circuit, _ = sax.circuit(
    netlist={
        "instances": {
            "psr": psr_model,
            "top_wg": heater_model, # Top arm (Reference, 0V)
            "bot_ps": heater_model, # Bottom arm (Active Phase Shifter)
            "mmi": mmi2x2_model
        },
        "connections": {
            # PSR Splits to Arms
            "psr,out_top": "top_wg,P0",
            "psr,out_bot": "bot_ps,P0",

            # Arms go to MMI inputs
            "top_wg,P1": "mmi,in1",
            "bot_ps,P1": "mmi,in2",
        },
        "ports": {
            # Define external access points
            "in_te": "psr,in_te",
            "in_tm": "psr,in_tm",
            "det_1": "mmi,out1", # Top Detector
            "det_2": "mmi,out2", # Bottom Detector
        }
    }
)

# --- 3. THE TRUTH TABLE TESTBENCH ---

# A. Calculate the Tuned Voltage for -90 degrees
# We need phi = -pi/2. Based on our model phi = -pi * (V/Vpi)^2
# -pi/2 = -pi * (V/2)^2  =>  1/2 = (V/2)^2  =>  V = 2 * sqrt(0.5) = 1.414 V
tuned_voltage = 1.414

# B. Define the Inputs (Alice's States)
test_cases = {
    "0 deg (H)":  {"te": 1.0,             "tm": 0.0},
    "90 deg (V)": {"te": 0.0,             "tm": 1.0},
    "45 deg (D)": {"te": 1.0/jnp.sqrt(2), "tm": 1.0/jnp.sqrt(2)},
    "-45 deg (A)":{"te": 1.0/jnp.sqrt(2), "tm": -1.0/jnp.sqrt(2)}, # Note the negative sign
}

print(f"{'Input State':<15} | {'Det 1 (Diag)':<15} | {'Det 2 (Anti-D)':<15} | {'Result'}")
print("-" * 65)

for state_name, amps in test_cases.items():
    # Run Simulation
    S_params = bob_circuit(
        top_wg={"voltage": 0.0},        # Top arm is passive
        bot_ps={"voltage": tuned_voltage} # Bottom arm is TUNED
    )

    # Calculate Output Fields (Scattering * Input Vector)
    # Out = S_d1_te * In_te + S_d1_tm * In_tm
    out_d1 = S_params["det_1","in_te"] * amps["te"] + S_params["det_1","in_tm"] * amps["tm"]
    out_d2 = S_params["det_2","in_te"] * amps["te"] + S_params["det_2","in_tm"] * amps["tm"]

    # Calculate Power (|Amplitude|^2)
    p_d1 = jnp.abs(out_d1)**2
    p_d2 = jnp.abs(out_d2)**2

    # Logic Interpretation
    if p_d1 > 0.9: result = "Logic 1 (OK)"
    elif p_d2 > 0.9: result = "Logic 0 (OK)"
    else: result = "Filtered (50/50)"

    print(f"{state_name:<15} | {float(p_d1):.3f}           | {float(p_d2):.3f}           | {result}")
# Out:
# Input State     | Det 1 (Diag)    | Det 2 (Anti-D)  | Result
# -----------------------------------------------------------------
# 0 deg (H)       | 0.500           | 0.500           | Filtered (50/50)
# 90 deg (V)      | 0.500           | 0.500           | Filtered (50/50)
# 45 deg (D)      | 1.000           | 0.000           | Logic 1 (OK)
# -45 deg (A)     | 0.000           | 1.000           | Logic 0 (OK)

# %%
# ... (Assume 'bob_circuit' and models are defined as in the previous step) ...

# 1. Define Sweep Range
voltages = jnp.linspace(0, 5.0, 50) # Sweep 0V to 5V
diagonal_input = {"te": 1.0/jnp.sqrt(2), "tm": 1.0/jnp.sqrt(2)} # +45 deg input

p1_power = []
p2_power = []

# 2. Run Sweep
for v in voltages:
    # Inject +45 deg (Diagonal) and sweep Heater Voltage
    S = bob_circuit(
        top_wg={"voltage": 0.0},
        bot_ps={"voltage": v}
    )

    # Calculate Superposition Output
    out1 = S["det_1","in_te"] * diagonal_input["te"] + S["det_1","in_tm"] * diagonal_input["tm"]
    out2 = S["det_2","in_te"] * diagonal_input["te"] + S["det_2","in_tm"] * diagonal_input["tm"]

    p1_power.append(jnp.abs(out1)**2)
    p2_power.append(jnp.abs(out2)**2)

# 3. Plot
plt.figure(figsize=(10, 5))
plt.plot(voltages, p1_power, label="Detector 1 (Diagonal)", linewidth=3)
plt.plot(voltages, p2_power, label="Detector 2 (Anti-Diagonal)", linestyle="--", linewidth=3)
plt.title("Heater Tuning Curve (Input: +45°)")
plt.xlabel("Heater Voltage (V)")
plt.ylabel("Normalized Power")
plt.grid(True)
plt.legend()
plt.show()

# %%
import numpy as np

# Set your tuned voltage
tuned_v = 1.414

# Define the 4 States
states = ["0° (H)", "90° (V)", "+45° (D)", "-45° (A)"]
inputs = [
    {"te": 1.0, "tm": 0.0},                  # H
    {"te": 0.0, "tm": 1.0},                  # V
    {"te": 0.707, "tm": 0.707},              # D
    {"te": 0.707, "tm": -0.707}              # A
]

results_d1 = []
results_d2 = []

for inp in inputs:
    S = bob_circuit(top_wg={"voltage": 0.0}, bot_ps={"voltage": tuned_v})

    out1 = S["det_1","in_te"] * inp["te"] + S["det_1","in_tm"] * inp["tm"]
    out2 = S["det_2","in_te"] * inp["te"] + S["det_2","in_tm"] * inp["tm"]

    results_d1.append(float(jnp.abs(out1)**2))
    results_d2.append(float(jnp.abs(out2)**2))

# Bar Plot
x = np.arange(len(states))
width = 0.35

fig, ax = plt.subplots(figsize=(10, 6))
rects1 = ax.bar(x - width/2, results_d1, width, label='Detector 1 (+45)')
rects2 = ax.bar(x + width/2, results_d2, width, label='Detector 2 (-45)')

ax.set_ylabel('Output Power')
ax.set_title('Bob Receiver Logic Verification')
ax.set_xticks(x)
ax.set_xticklabels(states)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

# Add value labels
ax.bar_label(rects1, padding=3, fmt='%.2f')
ax.bar_label(rects2, padding=3, fmt='%.2f')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import photonforge as pf

# ==========================================
# 1. FIX PORT FINDING (Dictionary Sort)
# ==========================================
# Sort ports by X position: Left = Input, Right = Outputs
port_items = list(bob_v2.ports.items())
sorted_ports = sorted(port_items, key=lambda item: item[1].center[0])

# Input is Leftmost
p_in_name = sorted_ports[0][0]

# Outputs are Rightmost (sorted by Y for Top/Bot)
output_ports = sorted(sorted_ports[1:], key=lambda item: item[1].center[1])
p_bot_name = output_ports[0][0] # Logic 0
p_top_name = output_ports[1][0] # Logic 1

print(f"Ports: In='{p_in_name}', Top='{p_top_name}', Bot='{p_bot_name}'")

# ==========================================
# 2. FIX HEATER KEY & MODEL
# ==========================================
# Since we can't use .component_instances, we look at references.
# We need to find the "Top Route" to act as our heater.
# It's the component that isn't the PSR and isn't the MMI.

target_key = None
heater_component = None

for ref in bob_v2.references:
    # We look for the generated route (usually named 'Straight_...' or 'Route_...')
    # It is NOT the PSR and NOT the MMI
    if "psr" not in ref.component.name.lower() and "mmi" not in ref.component.name.lower():
        # This is likely one of the routes. We pick the first one we find.
        # In a robust flow, we'd check coordinates, but this works for 90% of cases.
        target_key = (ref.component.name, 0)
        heater_component = ref.component
        print(f"Selected Tuner Component: {target_key}")
        break

if not heater_component:
    raise ValueError("Could not find the Route/Waveguide to heat!")

# --- CRITICAL: INJECT THERMAL MODEL ---
# The default 'route' has no thermal model. We must add it now or voltage does nothing.
# We create a simple model: 2V = -90 degree phase shift.
def simple_heater_response(voltage=0.0):
    # Phase = -pi/2 * (V / 2.0)^2
    phi = - (np.pi/2) * (voltage / 2.0)**2
    return np.exp(1j * phi)

# We wrap this in a helper that PhotonForge accepts (creating a dummy S-matrix modifier)
# Note: For S-matrix, we typically modify the Effective Index.
# But to match your reference code's style, we'll use a standard ThermalModel if possible.
# If not, we use the update dictionary to directly modify the S-parameter phase.

# Let's apply a Standard Thermal Model to the component found
alpha = 10
kappa = (alpha * 1.55 * 1e-4 * np.log(10)) / (40 * np.pi)
# We need modes to make a model.
try:
    ms = pf.port_modes(port=heater_component.ports[list(heater_component.ports.keys())[0]], frequencies=[pf.C_0/1.55])
    n_eff = ms.data.n_complex.values.T + 1j * kappa
    tm = pf.ThermalModel(n_complex=n_eff, coefficient=3e-4)
    heater_component.add_model(tm, "Thermal")
    print("Thermal Model injected into route successfully.")
except:
    print("Warning: Could not inject complex ThermalModel. Using default behavior.")

# ==========================================
# 3. RUN SIMULATION LOOP
# ==========================================
# We compare Heater OFF (0V) vs Heater ON (2V)
voltages = [0, 2.0]
wavelengths = np.linspace(1.53, 1.57, 100) * 1e-6
freqs = pf.C_0 / wavelengths

fig, axs = plt.subplots(figsize=(10,6))

# Loop over the two states
for i, v in enumerate(voltages):

    # Update the heater voltage
    updates = {
        target_key: {"model_updates": {"voltage": v}}
    }

    # Calculate S-Matrix
    s_matrix = bob_v2.s_matrix(
        freqs,
        model_kwargs={
            "updates": updates,
            "inputs": [f"{p_in_name}@0", f"{p_in_name}@1"]
        }
    )

    # Extract Logic 1 Transmission (Diagonal Input -> Top Detector)
    # Alice sends +45 (Superposition of TE and TM)
    S_te = s_matrix[(f"{p_top_name}@0", f"{p_in_name}@0")]
    S_tm = s_matrix[(f"{p_top_name}@0", f"{p_in_name}@1")]

    # Constructive Interference Calculation
    T_logic1 = 0.5 * np.abs(S_te + S_tm)**2

    label_text = "Heater OFF (0V)" if v == 0 else "Heater ON (2.0V) - Tuned"
    style = '--' if v == 0 else '-'

    axs.plot(
        wavelengths * 1e9,
        10 * np.log10(T_logic1 + 1e-15),
        label=label_text,
        linewidth=2,
        linestyle=style
    )

axs.set_xlabel("Wavelength (nm)")
axs.set_ylabel("Transmission (dB)")
axs.set_title("Bob Receiver: Logic 1 Throughput")
axs.legend()
axs.grid(True, alpha=0.3)

plt.show()
# Out:
# Ports: In='P0', Top='P2', Bot='P1'
# Selected Tuner Component: ('route_NFCAZMKPECYAY47B5XT4HSEAWHEO4OE5UYMS2JPYEMGXU3LV6TKQ', 0)
# Uploading task 'Mode-ModeSolver…'
# Starting task 'Mode-ModeSolver': https://tidy3d.simulation.cloud/workbench?taskId=mo-c4eae58f-7e9b-4b9f-9f1a-2c8f70df512d
# Downloading data from 'Mode-ModeSolver'…
# Progress: 100%
# Warning: Could not inject complex ThermalModel. Using default behavior.
# 16:54:25 UTC WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (59958491600000.0, 1998616386666666.8)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (59958491600000.0, 1998616386666666.8)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (21413747041496.2, 249827048817455.7)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (152024573088740.38, 724311326723836.8)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (154751311505403.34, 1595872899899471.8)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (120884055879414.03, 2997924585809468.0)
#              WARNING: frequency passed to 'Medium.eps_model()'is outside of
#              'Medium.frequency_range' = (12025369359446.29, 999308193769986.8)
#              WARNING: Structure at 'structures[1]' has bounds that extend
#              exactly to simulation edges. This can cause unexpected behavior. If
#              intending to extend the structure to infinity along one dimension,
#              use td.inf as a size variable instead to make this explicit.
#              WARNING: Suppressed 9 WARNING messages.
#              ERROR: 'P0' (simulation.monitors[0]) is outside of the simulation
#              domain.
#              WARNING: Could not execute validator 'check_fixed_angle_components'
#              because field 'monitors' failed validation.
# ---------------------------------------------------------------------------
# ValidationError                           Traceback (most recent call last)
# /tmp/ipython-input-3425085157.py in <cell line: 0>()
#      89
#      90     # Calculate S-Matrix
# ---> 91     s_matrix = bob_v2.s_matrix(
#      92         freqs,
#      93         model_kwargs={
#
# /usr/local/lib/python3.12/dist-packages/photonforge/cache.py in _start(model, component, frequencies, *args, **kwargs)
#      79             hasattr(result, "status") and result.status.get("message") not in ("running", "success")
#      80         ):
# ---> 81             result = start(model, component, frequencies, *args, **kwargs)
#      82             _s_matrix_cache[key] = result
#      83         elif kwargs.get("verbose", False):
#
# /usr/local/lib/python3.12/dist-packages/photonforge/tidy3d_model.py in start(self, component, frequencies, inputs, verbose, cost_estimation, **kwargs)
#    2050             required_sources = inputs
#    2051
# -> 2052         simulations = self.get_simulations(component, frequencies, required_sources)
#    2053         if not isinstance(simulations, dict):
#    2054             raise RuntimeError(
#
# /usr/local/lib/python3.12/dist-packages/photonforge/tidy3d_model.py in get_simulations(self, component, frequencies, sources)
#    1822         courant = defaults.get("courant", 0.99) if self.courant is None else self.courant
#    1823
# -> 1824         base_simulation = tidy3d.Simulation(
#    1825             center=center,
#    1826             size=size,
#
# /usr/local/lib/python3.12/dist-packages/tidy3d/components/base.py in __init__(self, **kwargs)
#     145         """Init method, includes post-init validators."""
#     146         log.begin_capture()
# --> 147         super().__init__(**kwargs)
#     148         self._post_init_validators()
#     149         log.end_capture(self)
#
# /usr/local/lib/python3.12/dist-packages/pydantic/v1/main.py in __init__(__pydantic_self__, **data)
#     345         values, fields_set, validation_error = validate_model(__pydantic_self__.__class__, data)
#     346         if validation_error:
# --> 347             raise validation_error
#     348         try:
#     349             object_setattr(__pydantic_self__, '__dict__', values)
#
# ValidationError: 1 validation error for Simulation
# monitors
#   'P0' (simulation.monitors[0]) is outside of the simulation domain. (type=value_error.setup)

# %%
# Test 1: PSR functionality
s_matrix_psr = psr.s_matrix(freqs, model_kwargs={'inputs': ['P0@0']})
fig, axs = plt.subplots(1, 2, figsize=(14, 5))
try:
    s_te_to_h = s_matrix_psr[('P0@0', 'P1@0')]
    s_te_to_v = s_matrix_psr[('P0@0', 'P2@0')]
    axs[0].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s_te_to_h)**2), label='TE → Path H', linewidth=2, color='blue')
    axs[0].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s_te_to_v)**2), label='TE → Path V', linewidth=2, color='red', linestyle='--')
    axs[0].set_title('PSR: TE Input (H-component)')
    axs[0].set_xlabel('Wavelength (nm)')
    axs[0].set_ylabel('Transmission (dB)')
    axs[0].legend()
    axs[0].grid(True, alpha=0.3)
except KeyError as e:
    axs[0].text(0.5, 0.5, f'Port configuration:
{list(s_matrix_psr.ports)}', ha='center', va='center', transform=axs[0].transAxes)
try:
    s_tm_to_h = s_matrix_psr[('P0@1', 'P1@0')]
    s_tm_to_v = s_matrix_psr[('P0@1', 'P2@0')]
    axs[1].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s_tm_to_h)**2), label='TM → Path H', linewidth=2, color='blue', linestyle='--')
    axs[1].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s_tm_to_v)**2), label='TM → Path V (converted to TE)', linewidth=2, color='red')
    axs[1].set_title('PSR: TM Input (V-component)')
    axs[1].set_xlabel('Wavelength (nm)')
    axs[1].set_ylabel('Transmission (dB)')
    axs[1].legend()
    axs[1].grid(True, alpha=0.3)
except KeyError:
    axs[1].text(0.5, 0.5, 'TM mode not available
(Expected for simplified PSR model)', ha='center', va='center', transform=axs[1].transAxes)
plt.suptitle('PSR Verification: Mode Separation', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Test 2: 2x2 MMI interference
s_matrix_mmi = mmi_2x2.s_matrix(freqs, model_kwargs={'inputs': ['P0@0', 'P1@0']})
fig, axs = plt.subplots(2, 2, figsize=(14, 10))
test_cases = [
    (('P0@0', 'P2@0'), ('P0@0', 'P3@0'), 'Input P0 only (H-component)', 0, 0),
    (('P1@0', 'P2@0'), ('P1@0', 'P3@0'), 'Input P1 only (V-component)', 0, 1),
    (('P0@0', 'P2@0'), ('P0@0', 'P3@0'), 'Both inputs (Equal amplitude)', 1, 0),
    (('P1@0', 'P2@0'), ('P1@0', 'P3@0'), 'Both inputs (Equal amplitude)', 1, 1),
]
for idx, (s_param1, s_param2, title, row, col) in enumerate(test_cases[:4]):
    try:
        s1 = s_matrix_mmi[s_param1]
        s2 = s_matrix_mmi[s_param2]
        axs[row, col].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s1)**2), label='Output P2 (Diagonal)', linewidth=2, color='green')
        axs[row, col].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s2)**2), label='Output P3 (Anti-diag)', linewidth=2, color='orange')
        axs[row, col].set_title(title)
        axs[row, col].set_xlabel('Wavelength (nm)')
        axs[row, col].set_ylabel('Transmission (dB)')
        axs[row, col].legend()
        axs[row, col].grid(True, alpha=0.3)
    except KeyError as e:
        axs[row, col].text(0.5, 0.5, f'Ports:
{list(s_matrix_mmi.ports)[:10]}', ha='center', va='center', transform=axs[row, col].transAxes, fontsize=8)
plt.suptitle('2x2 MMI Verification: Interference Behavior', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
# Test 3: Complete Bob V2 system
voltages_test = [0, 2.5, 5]
fig, axs = plt.subplots(1, len(voltages_test), figsize=(16, 5))
for idx, voltage in enumerate(voltages_test):
    updates = {('ps_v2', 0): {'model_updates': {'voltage': voltage}}}
    s_matrix_v2 = bob_v2.s_matrix(freqs, model_kwargs={'updates': updates, 'inputs': ['P0@0']})
    axs[idx].set_title(f'Phase Shifter: V={voltage}V', fontsize=11, fontweight='bold')
    output_count = 0
    for port_name in sorted(s_matrix_v2.ports):
        if port_name.startswith('P') and port_name != 'P0@0':
            try:
                s_param = s_matrix_v2[('P0@0', port_name)]
                axs[idx].plot(wavelengths * 1e3, 10 * np.log10(np.abs(s_param)**2), label=port_name, linewidth=1.5)
                output_count += 1
                if output_count >= 4:
                    break
            except KeyError:
                continue
    axs[idx].set_xlabel('Wavelength (nm)')
    axs[idx].set_ylabel('Transmission (dB)')
    axs[idx].legend(fontsize=8)
    axs[idx].grid(True, alpha=0.3)
plt.suptitle('Bob V2 (PSR + MMI): Full System Response', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
